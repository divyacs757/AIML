# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('D:/dip(AIML(cse))/kaggle/House_Rent_Dataset.csv')
df=pd.DataFrame(data)
df
# Out:
#        Posted On  BHK   Rent    Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100.0  Ground out of 2   Super Area
# 1     2022-05-13    2  20000     NaN       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000.0       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800.0       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850.0       1 out of 2  Carpet Area
# ...          ...  ...    ...     ...              ...          ...
# 4741  2022-05-18    2  15000  1000.0       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000.0       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750.0       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500.0     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000.0       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
df.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 4
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
mean=df['Size'].mean()
df['Size']=df['Size'].fillna(mean)

# %%
df.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
plt.figure(figsize=(6,4))
plt.scatter(df.index,df['Rent'])

# %%
q1=df['Rent'].quantile(0.25)
q3=df['Rent'].quantile(0.75)
iqr=q3-q1
upper_bound=q3+1.5*iqr
lower_bound=q1-1.5*iqr

# %%
outer=df[(df['Rent']>=lower_bound)&(df['Rent']<=upper_bound)]
plt.scatter(outer.index,outer['Rent'].values)

# %%
count=df['BHK'].value_counts()
plt.figure(figure=(6,6))
plt.pie(countlabels=count.index,autopct='1%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x110f5baf410>,
# ...
#  [Text(0.07857215807019313, 1.0971902369125388, '2'),
#   Text(-0.8891477096255759, -0.6476236179044065, '1'),
#   Text(0.582458233063855, -0.9331357922275473, '3'),
#   Text(1.085800166856716, -0.1761760416569967, '4'),
#   Text(1.0997047936394952, -0.025482677377301647, '5'),
#   Text(1.0999845760668134, -0.005825153655716238, '6')],
#  [Text(0.042857540765559886, 0.5984674019522938, '147.7%'),
#   Text(-0.4849896597957686, -0.35324924612967623, '124.6%'),
#   Text(0.31770449076210266, -0.5089831593968439, '123.1%'),
#   Text(0.5922546364672996, -0.0960960227219982, '14.0%'),
#   Text(0.5998389783488155, -0.013899642205800897, '10.4%'),
#   Text(0.5999915869455346, -0.003177356539481584, '10.2%')])

# %%
plt.scatter(df['Size'],df['Rent'])

# %%
df['owener_name']=df[['City','Furnishing Status']].sum()
df
# Out:
#        Posted On  BHK   Rent         Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100.000000  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   967.666596       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000.000000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800.000000       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850.000000       1 out of 2  Carpet Area
# ...          ...  ...    ...          ...              ...          ...
# 4741  2022-05-18    2  15000  1000.000000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000.000000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750.000000       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500.000000     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000.000000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# ...

# %%
df.drop('owener name',axis=1)
# Out:
#        Posted On  BHK   Rent         Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100.000000  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   967.666596       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000.000000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800.000000       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850.000000       1 out of 2  Carpet Area
# ...          ...  ...    ...          ...              ...          ...
# 4741  2022-05-18    2  15000  1000.000000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000.000000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750.000000       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500.000000     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000.000000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# ...

# %%
owener_name=['divya','bhoomi','tanu','sanju','sinchu']
df['owener_name']=np.random.choice(owener_name,size=len(df))
df
# Out:
#        Posted On  BHK   Rent         Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100.000000  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   967.666596       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000.000000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800.000000       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850.000000       1 out of 2  Carpet Area
# ...          ...  ...    ...          ...              ...          ...
# 4741  2022-05-18    2  15000  1000.000000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000.000000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750.000000       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500.000000     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000.000000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# ...
