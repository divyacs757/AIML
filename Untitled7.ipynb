# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv('Downloads/studentsinfo.csv')
print(df)
# Out:
#    id    name gender  age  study_hours  attendance(%)  marks_math  \
# 0   1    riya      f   17          3.5             95          92
# 1   2   arjun      m   18          2.0             82          80
# 2   3   sneha      f   17          4.0             98          89
# 3   4  rakesh      m   19          1.5             70          68
# 4   5   aditi      f   18          3.8             92          93
# 5   6   kiran      m   18          2.5             85          75
# 6   7  anjali      f   17          4.2             99          95
# 7   8  manish      m   19          1.0             65          58
#
#    marks_scince grade
# 0            92     a
# 1            80     b
# 2            89     a
# 3            68     c
# 4            93     a
# 5            75     b
# 6            95     a
# 7            50     d

# %%
plt.hist(df['marks_math'])
# Out:
# (array([1., 0., 1., 0., 1., 1., 0., 0., 1., 3.]),
#  array([58. , 61.7, 65.4, 69.1, 72.8, 76.5, 80.2, 83.9, 87.6, 91.3, 95. ]),
#  <BarContainer object of 10 artists>)

# %%
df['grade'].value_counts().plot(kind='bar',x='grade',y='id')
# Out:
# <Axes: xlabel='grade'>

# %%
plt.boxplot(df['study_hours'])
plt.ylabel('study hours')
# Out:
# Text(0, 0.5, 'study hours')

# %%
df.plot(kind='hist',x='study_hours',y='id')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['gender'].value_counts().plot(kind='pie',autopct='1%.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
plt.bar(attendance_freq.index, attendance_freq.values)
plt.show()

# %%
plt.scatter(df['study_hours'],df['marks_math'],color='pink')
plt.grid(True)
plt.show()

# %%
plt.scatter(df['attendance(%)'],df['marks_math'])

# %%
marks=df.groupby('gender')['marks_math'].mean()
plt.bar(marks.index,marks.values)
# Out:
# <BarContainer object of 2 artists>

# %%
plt.plot(df['name'],df['marks_math'])
plt.plot(df['name'],df['marks_scince'])
plt.show()

# %%
df.boxplot('marks_math','grade')
# Out:
# <Axes: title={'center': 'marks_math'}, xlabel='grade'>

# %%
bins = [60, 70, 80, 90, 100]
labels = ['60–70', '70–80', '80–90', '90–100']
df['attendance_Range'] = pd.cut(df['attendance(%)'], bins=bins, labels=labels, right=True)

attendance_freq = df['attendance_Range'].value_counts().sort_index()

plt.figure(figsize=(6,4))
plt.bar(attendance_freq.index, attendance_freq.values, color='mediumseagreen')
plt.title('Frequency of Attendance Percentage Ranges')
plt.xlabel('Attendance Range(%)')
plt.ylabel('Number of Students')
plt.grid(axis='y')
plt.show()
