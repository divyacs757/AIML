# %% [markdown]
# # Experiment-11

# %% [markdown]
# ## 1.Consider Mall_Customer Datset and perform the following operations
# ### a)Using Elbow method find the optimal number of clusters
# ### b) Train a K-Means cluster algorithm and Training dataset
# ### c)Evaluate the model using inertia and other metrics (silhouette)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
import numpy as np

# %%
# Load dataset
df = pd.read_csv("D:/dip(AIML(cse))/kaggle/Mall_Customers.csv")

print("Dataset Head:\n", df.head())
# Out:
# Dataset Head:
#     CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
X = df[['Annual Income (k$)', 'Spending Score (1-100)']].values
X = StandardScaler().fit_transform(X)

# %% [markdown]
# ## a)Using Elbow method find the optimal number of clusters

# %%
#inertias
inertias = []
for k in range(1, 11):
    km = KMeans(n_clusters=k, random_state=0)
    km.fit(X)
    inertias.append(km.inertia_)

plt.plot(range(1, 11), inertias, marker='o')
plt.title("Elbow Method")
plt.xlabel("k")
plt.ylabel("Inertia")
plt.show()

# %% [markdown]
# ## b) Train a K-Means cluster algorithm and Training dataset

# %%
# ---- 2. K-Means ----
kmeans = KMeans(n_clusters=5, random_state=0)
labels = kmeans.fit_predict(X)

plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.title("K-Means Clustering")
plt.show()

# %% [markdown]
# ## c)Evaluate the model using inertia and other metrics (silhouette)

# %%
# Silhouette Index
score = silhouette_score(X, labels)
print('Silhouette Index:', score)
# Out:
# Silhouette Index: 0.5546571631111091

# %%
print("Inertia:", kmeans.inertia_)
# Out:
# Inertia: 65.56840815571681
